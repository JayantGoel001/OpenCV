# %%
import cv2
import numpy as np

import os

cap = cv2.VideoCapture(0)

classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

name = input("Enter your Name : ")

pics = int(input("Enter number of pics : "))

list_faces = []

while True:

    ret, frame = cap.read()

    if ret:

        faces = classifier.detectMultiScale(frame)

        if len(faces) > 0:

            np_faces = np.array(faces)
            best_index = np.product(np_faces[:, 2:], axis=1).argmax()
            x, y, w, h = faces[best_index]
            crop = frame[y:y+h, x:x+w]

            face_img = cv2.resize(crop, (100, 100))

            face_gray = cv2.cvtColor(face_img, cv2.COLOR_RGB2GRAY)

            face_flat = face_gray.flatten()

            cv2.imshow("face", face_img)

        cv2.imshow("My video", frame)

    key = cv2.waitKey(1)

    if ord("q") == key:
        break

    if ord("c") == key:
        if ret and len(faces) > 0:
            list_faces.append(face_flat)
            print("Captured faces ", len(list_faces))

            if len(list_faces) == pics:
                break



X = np.array(list_faces)

y = np.full((pics, 1), name)

data = np.hstack([y, X])

print(data.shape, data.dtype)

if os.path.exists("faces.npy"):
    old = np.load("faces.npy")
    total = np.vstack([old, data])
    np.save("faces.npy", total)
else:
    np.save("faces.npy", data)

cap.release()
cv2.destroyAllWindows()
# Out:
# Enter your Name :  unknown
# Enter number of pics :  20
# Captured faces  1
# Captured faces  2
# Captured faces  3
# Captured faces  4
# Captured faces  5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8b4df100bb8f> in <module>
#      58 y = np.full((pics, 1), name)
#      59
# ---> 60 data = np.hstack([y, X])
#      61
#      62 print(data.shape, data.dtype)
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     343         return _nx.concatenate(arrs, 0)
#     344     else:
# --> 345         return _nx.concatenate(arrs, 1)
#     346
#     347
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 20 and the array at index 1 has size 5

# %%
import cv2
import numpy as np

import os
from sklearn.neighbors import KNeighborsClassifier

data = np.load("faces.npy")

X = data[:, 1:].astype(int)

y = data[:, 0]

model = KNeighborsClassifier()
model.fit(X, y)

cap = cv2.VideoCapture(0)

classifier = cv2.CascadeClassifier(
    "haarcascade_frontalface_default.xml")

while True:

    ret, frame = cap.read()

    if ret:

        faces = classifier.detectMultiScale(frame)

        if len(faces) > 0:
            np_faces = np.array(faces)
            best_index = np.product(np_faces[:, 2:], axis=1).argmax()
            x, y, w, h = faces[best_index]
            crop = frame[y:y + h, x:x + w]

            face_img = cv2.resize(crop, (100, 100))

            face_gray = cv2.cvtColor(face_img, cv2.COLOR_RGB2GRAY)

            face_flat = face_gray.flatten()

            pred_name = model.predict([face_flat])
            print(pred_name)

            cv2.putText(frame, pred_name[0], (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 5)
        cv2.imshow("My video ", frame)

    key = cv2.waitKey(1)

    if ord("q") == key:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['kani']
# ['kani']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['kani']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['kani']
# ['kani']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['kani']
# ['kani']
# ['kani']
# ['kani']
# ['kani']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['yashi']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['yashi']
# ['kani']
# ['kani']
# ['kani']
# ['kani']
# ['Jayant']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['kani']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
# ['Jayant']
